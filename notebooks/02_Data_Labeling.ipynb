# %%
import pandas as pd

df = pd.read_csv("../data/scraped_telegram_data.csv")

# Select a random sample of 50 messages to label
sample_df = df.sample(n=50, random_state=42)

# Print them out to copy-paste into a text editor for labeling
for msg in sample_df["text"]:
    print(msg)
    print("-" * 20)
# Out:
# **🔢****🔢****🔢****   ****🔠****🔠****🔠****
# ****🔠****🔠****🔠****🔠****🔠****🔠****🔠****🔠**** ****🔠****🔠****🔠****
#
# **🖐**ኳሊቲ የሆኑ 110 ፍሬ የያዘ የድስት እና ቢላ  ማንኪያ ሹካ  ፓኬጅ
# **👋** እስቴለስ እስቲል የሆኑ ወፋፍራም 7 ድስቶች
# **👋** 1 መጥበሻ
# **👋** 12 ሹካ ፤ 12 የሻይ ማንኪያ ፤ 12 የገበታ ቢላ ፤ 12 የሾርባ መሰኪያዎች ያሉት
# **👋** 5 set ቢላ ያለው
# **👋** 1 ቦይለር ያለው
# **👋** 1 መክተፊያ
# **👋** 1 ባለ ሁለት ምሳቃ
# **👋** 1 የነጭ ሽንኩርት መጨፍለቂያ
# **👋** የካሮት ና የድንች መላጫዎች
# **👋** ሌሎችንም አንድ ላይ ሰብስቦ የያዘ ምርጥ እቃ **
# 👋** ለቤት ቢሉ ለስጦታ ተመራጭ
# ****👋**** ለአዲስ ሙሽሮች ለስጦታ ተመራጭ
#
#           **ዋጋ:-**21,500****💵**
#
# 📍ውስን ፍሬ ነው ያለን/ Limited Stock
#
# 🏢 አድራሻ ቁ.1 👉 መገናኛ ታሜ ጋስ ህንፃ ጎን ስሪ ኤም ሲቲ ሞል  ሁለተኛ ፎቅ ቢሮ ቁ. SL-05A(ከ ሊፍቱ ፊት ለ ፊት)
#
# 📍ቁ.2 👉ለቡ  መዳህኒዓለም ቤተ/ክርስቲያን 100ሜ ወደ ሙዚቃ ቤት ከፍ ብሎ  #ዛም_ሞል 2ኛ ፎቅ ቢሮ.ቁ 214
#
#
#     📲 0909522840
#     📲 0923350054
#
# 👍ለቡ ቅርንጫፍ📲0973611819
#
#
# 🔖
# 💬  በTelegram ለማዘዝ ⤵️ ይጠቀሙ
# @shager_onlinestore
#
# ለተጨማሪ ማብራሪያ የቴሌግራም ገፃችን⤵️
# https://t.me/Shageronlinestore
# --------------------
# ❇️ Adjustable Posture Corrector
#
# ⚡Corrector Belt
# ...
